# %% [markdown]
# ### Goal of notebook is to figure out the most frequent diseases in the MIMIC-III dataset and compare with top diseases in CSU dataset

# %%
import pandas as pd
import re
import numpy as np
import csv
import sys

from IPython.display import display, HTML

# %%
from icd9 import ICD9

# %%
mimic = pd.read_csv('/Users/ashley1/Documents/Stanford/Bustamante_lab/Vet_Data_Collaboration/Rivas_Zou_labs/CSU_Altud/R_directory/icd9NotesDataTable.csv')

display(mimic[:5])
# Out:
#    Unnamed: 0  HADM_ID  SUBJECT_ID  \
# 0           1   167853       22532
# 1           2   107527       13702
# 2           3   167118       13702
# 3           4   196489       13702
# 4           5   135453       26880
#
#                                            ICD9_CODE   CHARTDATE DESCRIPTION  \
# 0          01193-4254-42731-2639-2762-5070-5119-2113  2151-08-04      Report
# 1                 5191-49121-51881-486-2761-2449-311  2118-06-14      Report
# 2                      5191-5185-496-2762-45340-5533  2119-05-25      Report
# 3  51884-5849-34830-49121-2760-4160-3594-5780-276...  2124-08-18      Report
# 4  80506-5070-42823-2930-4538-E882-4280-4011-V450...  2162-03-25      Report
#
#                                                 TEXT  Level2ICD  \
# 0  Admission Date:  [**2151-7-16**]       Dischar...        NaN
# 1  Admission Date:  [**2118-6-2**]       Discharg...        NaN
# 2  Admission Date:  [**2119-5-4**]              D...        NaN
# 3  Admission Date:  [**2124-7-21**]              ...        NaN
# 4  Admission Date:  [**2162-3-3**]              D...        NaN
#
#                                          TopLevelICD  \
# 0                     11-425-427-263-276-507-511-211
# 1                        519-491-518-486-276-244-311
# 2                            519-518-496-276-453-553
# 3  518-584-348-491-276-416-359-578-530-487-553-V0...
# 4  805-507-428-293-453-E882-401-V4502-427-V1254-8...
#
#                                              V9
# 0                 cat:1-cat:8-cat:3-cat:9-cat:2
# 1                             cat:9-cat:3-cat:5
# 2                      cat:9-cat:3-cat:8-cat:10
# 3  cat:9-cat:11-cat:6-cat:3-cat:8-cat:10-cat:19
# 4        cat:18-cat:9-cat:8-cat:5-cat:19-cat:17

# %%
mimic[:50].to_csv('mimic_sample', sep='\t', index=False)

# %%
mimic.shape
# Out:
# (52722, 10)

# %% [markdown]
# ### source for ICD-9 description file:
# https://www.cms.gov/Medicare/Coding/ICD9ProviderDiagnosticCodes/codes.html
#
# Note: apparently ICD9 hierarchies are rough at best and the recommendations are to map ICD9 codes over to SNOMED if looking to traverse hierarchies:
# http://forums.ohdsi.org/t/lack-of-icd9-hierarchy/249/4
#
# found github repo for traversing the ICD9 tree with descriptions:
# https://github.com/sirrice/icd9

# %%
#may be easier to merge in a flat description file:
desc = pd.read_csv('/Users/ashley1/repos/icd9/icd9/CMS32_DESC_SHORT_DX.txt', sep='\t', names='A')
desc
# Out:
#                                     A
# 0      0010  Cholera d/t vib cholerae
# 1        0011  Cholera d/t vib el tor
# 2                   0019  Cholera NOS
# 3                 0020  Typhoid fever
# 4           0021  Paratyphoid fever a
# 5           0022  Paratyphoid fever b
# 6           0023  Paratyphoid fever c
# 7         0029  Paratyphoid fever NOS
# 8          0030  Salmonella enteritis
# 9         0031  Salmonella septicemia
# 10     00320 Local salmonella inf NOS
# 11        00321 Salmonella meningitis
# 12         00322 Salmonella pneumonia
# 13         00323 Salmonella arthritis
# 14     00324 Salmonella osteomyelitis
# 15     00329 Local salmonella inf NEC
# 16     0038  Salmonella infection NEC
# 17     0039  Salmonella infection NOS
# 18         0040  Shigella dysenteriae
# 19            0041  Shigella flexneri
# 20              0042  Shigella boydii
# 21              0043  Shigella sonnei
# 22       0048  Shigella infection NEC
# 23              0049  Shigellosis NOS
# 24         0050  Staph food poisoning
# 25      0051  Botulism food poisoning
# 26     0052  Food pois d/t c. perfrin
# 27      0053  Food pois: clostrid NEC
# 28       0054  Food pois: v. parahaem
# 29     00581 Food poisn d/t v. vulnif
# ...                               ...
# 14537   V9009 Retain radioac frag NEC
# 14538   V9010 Retained metal frag NOS
# 14539  V9011 Retain magnet metal frag
# 14540   V9012 Retain nonmag meta frag
# 14541  V902  Retain plastic fragments
# 14542    V9031 Retained quills/spines
# 14543            V9032 Retained tooth
# 14544   V9033 Retained wood fragments
# 14545   V9039 Retain organic frag NEC
# 14546  V9081 Retained glass fragments
# 14547  V9083 Retain stone/crystl frag
# 14548             V9089 Retain FB NEC
# 14549        V909  Retain FB, mat NOS
# 14550    V9100 Twin gest-plac/sac NOS
# 14551  V9101 Twin gest-monochr/monoam
# 14552  V9102 Twin gest-monochr/diamni
# 14553  V9103 Twin gest-dich/diamniotc
# 14554  V9109 Twin gest-plac/sac undet
# 14555   V9110 Tripl gest-plac/sac NOS
# 14556  V9111 Triplet gest 2+ monochor
# 14557   V9112 Triplet gest 2+ monoamn
# 14558   V9119 Tripl gest-plac/sac und
# 14559    V9120 Quad gest-plac/sac NOS
# 14560  V9121 Quad gest 2+ monochorion
# 14561  V9122 Quad gest 2+ monoamniotc
# 14562  V9129 Quad gest-plac/sac undet
# 14563    V9190 Mult gest-plac/sac NOS
# 14564  V9191 Mult gest 2+ monochr NEC
# 14565  V9192 Mult gest 2+ monoamn NEC
# 14566  V9199 Mult gest-plac/sac undet
#
# [14567 rows x 1 columns]

# %%
desc['B'], desc['C'] = desc['A'].str.split(' ', 1).str
desc
# Out:
#                                     A      B                          C
# 0      0010  Cholera d/t vib cholerae   0010   Cholera d/t vib cholerae
# 1        0011  Cholera d/t vib el tor   0011     Cholera d/t vib el tor
# 2                   0019  Cholera NOS   0019                Cholera NOS
# 3                 0020  Typhoid fever   0020              Typhoid fever
# 4           0021  Paratyphoid fever a   0021        Paratyphoid fever a
# 5           0022  Paratyphoid fever b   0022        Paratyphoid fever b
# 6           0023  Paratyphoid fever c   0023        Paratyphoid fever c
# 7         0029  Paratyphoid fever NOS   0029      Paratyphoid fever NOS
# 8          0030  Salmonella enteritis   0030       Salmonella enteritis
# 9         0031  Salmonella septicemia   0031      Salmonella septicemia
# 10     00320 Local salmonella inf NOS  00320   Local salmonella inf NOS
# 11        00321 Salmonella meningitis  00321      Salmonella meningitis
# 12         00322 Salmonella pneumonia  00322       Salmonella pneumonia
# 13         00323 Salmonella arthritis  00323       Salmonella arthritis
# 14     00324 Salmonella osteomyelitis  00324   Salmonella osteomyelitis
# 15     00329 Local salmonella inf NEC  00329   Local salmonella inf NEC
# 16     0038  Salmonella infection NEC   0038   Salmonella infection NEC
# 17     0039  Salmonella infection NOS   0039   Salmonella infection NOS
# 18         0040  Shigella dysenteriae   0040       Shigella dysenteriae
# 19            0041  Shigella flexneri   0041          Shigella flexneri
# 20              0042  Shigella boydii   0042            Shigella boydii
# 21              0043  Shigella sonnei   0043            Shigella sonnei
# 22       0048  Shigella infection NEC   0048     Shigella infection NEC
# 23              0049  Shigellosis NOS   0049            Shigellosis NOS
# 24         0050  Staph food poisoning   0050       Staph food poisoning
# 25      0051  Botulism food poisoning   0051    Botulism food poisoning
# 26     0052  Food pois d/t c. perfrin   0052   Food pois d/t c. perfrin
# 27      0053  Food pois: clostrid NEC   0053    Food pois: clostrid NEC
# 28       0054  Food pois: v. parahaem   0054     Food pois: v. parahaem
# 29     00581 Food poisn d/t v. vulnif  00581   Food poisn d/t v. vulnif
# ...                               ...    ...                        ...
# 14537   V9009 Retain radioac frag NEC  V9009    Retain radioac frag NEC
# 14538   V9010 Retained metal frag NOS  V9010    Retained metal frag NOS
# 14539  V9011 Retain magnet metal frag  V9011   Retain magnet metal frag
# 14540   V9012 Retain nonmag meta frag  V9012    Retain nonmag meta frag
# 14541  V902  Retain plastic fragments   V902   Retain plastic fragments
# 14542    V9031 Retained quills/spines  V9031     Retained quills/spines
# 14543            V9032 Retained tooth  V9032             Retained tooth
# 14544   V9033 Retained wood fragments  V9033    Retained wood fragments
# 14545   V9039 Retain organic frag NEC  V9039    Retain organic frag NEC
# 14546  V9081 Retained glass fragments  V9081   Retained glass fragments
# 14547  V9083 Retain stone/crystl frag  V9083   Retain stone/crystl frag
# 14548             V9089 Retain FB NEC  V9089              Retain FB NEC
# 14549        V909  Retain FB, mat NOS   V909         Retain FB, mat NOS
# 14550    V9100 Twin gest-plac/sac NOS  V9100     Twin gest-plac/sac NOS
# 14551  V9101 Twin gest-monochr/monoam  V9101   Twin gest-monochr/monoam
# 14552  V9102 Twin gest-monochr/diamni  V9102   Twin gest-monochr/diamni
# 14553  V9103 Twin gest-dich/diamniotc  V9103   Twin gest-dich/diamniotc
# 14554  V9109 Twin gest-plac/sac undet  V9109   Twin gest-plac/sac undet
# 14555   V9110 Tripl gest-plac/sac NOS  V9110    Tripl gest-plac/sac NOS
# 14556  V9111 Triplet gest 2+ monochor  V9111   Triplet gest 2+ monochor
# 14557   V9112 Triplet gest 2+ monoamn  V9112    Triplet gest 2+ monoamn
# 14558   V9119 Tripl gest-plac/sac und  V9119    Tripl gest-plac/sac und
# 14559    V9120 Quad gest-plac/sac NOS  V9120     Quad gest-plac/sac NOS
# 14560  V9121 Quad gest 2+ monochorion  V9121   Quad gest 2+ monochorion
# 14561  V9122 Quad gest 2+ monoamniotc  V9122   Quad gest 2+ monoamniotc
# 14562  V9129 Quad gest-plac/sac undet  V9129   Quad gest-plac/sac undet
# 14563    V9190 Mult gest-plac/sac NOS  V9190     Mult gest-plac/sac NOS
# 14564  V9191 Mult gest 2+ monochr NEC  V9191   Mult gest 2+ monochr NEC
# 14565  V9192 Mult gest 2+ monoamn NEC  V9192   Mult gest 2+ monoamn NEC
# 14566  V9199 Mult gest-plac/sac undet  V9199   Mult gest-plac/sac undet
#
# [14567 rows x 3 columns]

# %%
desc.drop(['A'], inplace=True, axis=1)
desc
# Out:
#            B                          C
# 0       0010   Cholera d/t vib cholerae
# 1       0011     Cholera d/t vib el tor
# 2       0019                Cholera NOS
# 3       0020              Typhoid fever
# 4       0021        Paratyphoid fever a
# 5       0022        Paratyphoid fever b
# 6       0023        Paratyphoid fever c
# 7       0029      Paratyphoid fever NOS
# 8       0030       Salmonella enteritis
# 9       0031      Salmonella septicemia
# 10     00320   Local salmonella inf NOS
# 11     00321      Salmonella meningitis
# 12     00322       Salmonella pneumonia
# 13     00323       Salmonella arthritis
# 14     00324   Salmonella osteomyelitis
# 15     00329   Local salmonella inf NEC
# 16      0038   Salmonella infection NEC
# 17      0039   Salmonella infection NOS
# 18      0040       Shigella dysenteriae
# 19      0041          Shigella flexneri
# 20      0042            Shigella boydii
# 21      0043            Shigella sonnei
# 22      0048     Shigella infection NEC
# 23      0049            Shigellosis NOS
# 24      0050       Staph food poisoning
# 25      0051    Botulism food poisoning
# 26      0052   Food pois d/t c. perfrin
# 27      0053    Food pois: clostrid NEC
# 28      0054     Food pois: v. parahaem
# 29     00581   Food poisn d/t v. vulnif
# ...      ...                        ...
# 14537  V9009    Retain radioac frag NEC
# 14538  V9010    Retained metal frag NOS
# 14539  V9011   Retain magnet metal frag
# 14540  V9012    Retain nonmag meta frag
# 14541   V902   Retain plastic fragments
# 14542  V9031     Retained quills/spines
# 14543  V9032             Retained tooth
# 14544  V9033    Retained wood fragments
# 14545  V9039    Retain organic frag NEC
# 14546  V9081   Retained glass fragments
# 14547  V9083   Retain stone/crystl frag
# 14548  V9089              Retain FB NEC
# 14549   V909         Retain FB, mat NOS
# 14550  V9100     Twin gest-plac/sac NOS
# 14551  V9101   Twin gest-monochr/monoam
# 14552  V9102   Twin gest-monochr/diamni
# 14553  V9103   Twin gest-dich/diamniotc
# 14554  V9109   Twin gest-plac/sac undet
# 14555  V9110    Tripl gest-plac/sac NOS
# 14556  V9111   Triplet gest 2+ monochor
# 14557  V9112    Triplet gest 2+ monoamn
# 14558  V9119    Tripl gest-plac/sac und
# 14559  V9120     Quad gest-plac/sac NOS
# 14560  V9121   Quad gest 2+ monochorion
# 14561  V9122   Quad gest 2+ monoamniotc
# 14562  V9129   Quad gest-plac/sac undet
# 14563  V9190     Mult gest-plac/sac NOS
# 14564  V9191   Mult gest 2+ monochr NEC
# 14565  V9192   Mult gest 2+ monoamn NEC
# 14566  V9199   Mult gest-plac/sac undet
#
# [14567 rows x 2 columns]

# %%
desc.rename(columns={'conceptID':'conceptId', 'C':'term'}, inplace=True)
desc
# Out:
#       conceptId                       term
# 0          0010   Cholera d/t vib cholerae
# 1          0011     Cholera d/t vib el tor
# 2          0019                Cholera NOS
# 3          0020              Typhoid fever
# 4          0021        Paratyphoid fever a
# 5          0022        Paratyphoid fever b
# 6          0023        Paratyphoid fever c
# 7          0029      Paratyphoid fever NOS
# 8          0030       Salmonella enteritis
# 9          0031      Salmonella septicemia
# 10        00320   Local salmonella inf NOS
# 11        00321      Salmonella meningitis
# 12        00322       Salmonella pneumonia
# 13        00323       Salmonella arthritis
# 14        00324   Salmonella osteomyelitis
# 15        00329   Local salmonella inf NEC
# 16         0038   Salmonella infection NEC
# 17         0039   Salmonella infection NOS
# 18         0040       Shigella dysenteriae
# 19         0041          Shigella flexneri
# 20         0042            Shigella boydii
# 21         0043            Shigella sonnei
# 22         0048     Shigella infection NEC
# 23         0049            Shigellosis NOS
# 24         0050       Staph food poisoning
# 25         0051    Botulism food poisoning
# 26         0052   Food pois d/t c. perfrin
# 27         0053    Food pois: clostrid NEC
# 28         0054     Food pois: v. parahaem
# 29        00581   Food poisn d/t v. vulnif
# ...         ...                        ...
# 14537     V9009    Retain radioac frag NEC
# 14538     V9010    Retained metal frag NOS
# 14539     V9011   Retain magnet metal frag
# 14540     V9012    Retain nonmag meta frag
# 14541      V902   Retain plastic fragments
# 14542     V9031     Retained quills/spines
# 14543     V9032             Retained tooth
# 14544     V9033    Retained wood fragments
# 14545     V9039    Retain organic frag NEC
# 14546     V9081   Retained glass fragments
# 14547     V9083   Retain stone/crystl frag
# 14548     V9089              Retain FB NEC
# 14549      V909         Retain FB, mat NOS
# 14550     V9100     Twin gest-plac/sac NOS
# 14551     V9101   Twin gest-monochr/monoam
# 14552     V9102   Twin gest-monochr/diamni
# 14553     V9103   Twin gest-dich/diamniotc
# 14554     V9109   Twin gest-plac/sac undet
# 14555     V9110    Tripl gest-plac/sac NOS
# 14556     V9111   Triplet gest 2+ monochor
# 14557     V9112    Triplet gest 2+ monoamn
# 14558     V9119    Tripl gest-plac/sac und
# 14559     V9120     Quad gest-plac/sac NOS
# 14560     V9121   Quad gest 2+ monochorion
# 14561     V9122   Quad gest 2+ monoamniotc
# 14562     V9129   Quad gest-plac/sac undet
# 14563     V9190     Mult gest-plac/sac NOS
# 14564     V9191   Mult gest 2+ monochr NEC
# 14565     V9192   Mult gest 2+ monoamn NEC
# 14566     V9199   Mult gest-plac/sac undet
#
# [14567 rows x 2 columns]

# %%
tree = ICD9('codes.JSON')

# %%
type(tree)
# Out:
# icd9.ICD9

# %%
# list of top level codes (e.g., '001-139', ...)
toplevelnodes = tree.children
toplevelcodes = [node.code for node in toplevelnodes]
print '\t'.join(toplevelcodes)
# Out:
# 001-139	140-239	240-279	290-319	320-389	390-459	460-519	520-579	580-629	630-679	680-709	710-739	760-779	780-789	790-796	797	798	799	800-999	V01-V06	V07-V09	V10-V19	V20-V29	V30-V39	V40-V49	V50-V59	V60-V69	V70-V82	V83-V84	V85	V86	V87	V88	V89	E979	E849	E800-E807	E810-E819	E820-E825	E826-E829	E830-E838	E840-E845	E846-E848	E850-E858	E860-E869	E870-E876	E878-E879	E880-E888	E890-E899	E900-E909	E910-E915	E916-E928	E929	E930-E949	E959	E956	E954	E950	E951	E952	E953	E955	E957	E958	E960-E969	E970-E978	E980-E989	E990-E999

# %%
# get english description of ICD9 code
# prints: 'Cholera due to vibrio cholerae el tor'
#tree.find('001.1').description

# prints: 'ROOT'
#tree.description

# prints: 'Cholera'
#tree.find('001.1').parent.description

# also prints: 'Cholera'
tree.find('001').description
# Out:
# u'Cholera'

# %% [markdown]
# ### get most common diagnoses in MIMIC-III dataset:

# %%
#first split up the ICD_code column on "-":
#https://gist.github.com/jlln/338b4b0b55bd6984f883

def splitDataFrameList(df,target_column,separator):
    ''' df = dataframe to split,
    target_column = the column containing the values to split
    separator = the symbol used to perform the split
    returns: a dataframe with each entry for the target column separated, with each element moved into a new row. 
    The values in the other columns are duplicated across the newly divided rows.
    '''
    def splitListToRows(row,row_accumulator,target_column,separator):
        split_row = row[target_column].split(separator)
        for s in split_row:
            new_row = row.to_dict()
            new_row[target_column] = s
            row_accumulator.append(new_row)
    new_rows = []
    df.apply(splitListToRows,axis=1,args = (new_rows,target_column,separator))
    new_df = pd.DataFrame(new_rows)
    return new_df

# %%
mimic_parsed = splitDataFrameList(mimic,'ICD9_CODE','-')
# Out:
#    Unnamed: 0  HADM_ID  SUBJECT_ID  \
# 0           1   167853       22532
# 1           2   107527       13702
# 2           3   167118       13702
# 3           4   196489       13702
# 4           5   135453       26880
#
#                                            ICD9_CODE   CHARTDATE DESCRIPTION  \
# 0          01193-4254-42731-2639-2762-5070-5119-2113  2151-08-04      Report
# 1                 5191-49121-51881-486-2761-2449-311  2118-06-14      Report
# 2                      5191-5185-496-2762-45340-5533  2119-05-25      Report
# 3  51884-5849-34830-49121-2760-4160-3594-5780-276...  2124-08-18      Report
# 4  80506-5070-42823-2930-4538-E882-4280-4011-V450...  2162-03-25      Report
#
#                                                 TEXT  Level2ICD  \
# 0  Admission Date:  [**2151-7-16**]       Dischar...        NaN
# 1  Admission Date:  [**2118-6-2**]       Discharg...        NaN
# 2  Admission Date:  [**2119-5-4**]              D...        NaN
# 3  Admission Date:  [**2124-7-21**]              ...        NaN
# 4  Admission Date:  [**2162-3-3**]              D...        NaN
#
#                                          TopLevelICD  \
# 0                     11-425-427-263-276-507-511-211
# 1                        519-491-518-486-276-244-311
# 2                            519-518-496-276-453-553
# 3  518-584-348-491-276-416-359-578-530-487-553-V0...
# 4  805-507-428-293-453-E882-401-V4502-427-V1254-8...
#
#                                              V9
# 0                 cat:1-cat:8-cat:3-cat:9-cat:2
# 1                             cat:9-cat:3-cat:5
# 2                      cat:9-cat:3-cat:8-cat:10
# 3  cat:9-cat:11-cat:6-cat:3-cat:8-cat:10-cat:19
# 4        cat:18-cat:9-cat:8-cat:5-cat:19-cat:17

# %%
mimic_parsed.shape
# Out:
# (618998, 10)

# %%
list(mimic_parsed)
# Out:
# ['CHARTDATE',
#  'DESCRIPTION',
#  'HADM_ID',
#  'ICD9_CODE',
#  'Level2ICD',
#  'SUBJECT_ID',
#  'TEXT',
#  'TopLevelICD',
#  'Unnamed: 0',
#  'V9']

# %%
mimic2 = mimic_parsed.groupby('ICD9_CODE').count()
mimic2
# Out:
#            CHARTDATE  DESCRIPTION  HADM_ID  Level2ICD  SUBJECT_ID  TEXT  \
# ICD9_CODE
# 0030               2            2        2          0           2     2
# 0031               1            1        1          0           1     1
# 0038               2            2        2          0           2     2
# 0039               1            1        1          0           1     1
# 0041               3            3        3          0           3     3
# 0048               1            1        1          0           1     1
# 0049               1            1        1          0           1     1
# 0051               1            1        1          0           1     1
# 00581              2            2        2          0           2     2
# 0059               1            1        1          0           1     1
# 0071               1            1        1          0           1     1
# 0074               6            6        6          0           6     6
# 00804              1            1        1          0           1     1
# 00841              1            1        1          0           1     1
# 00843              1            1        1          0           1     1
# 00845           1428         1428     1428          0        1428  1428
# 00847              1            1        1          0           1     1
# 0085               4            4        4          0           4     4
# 00861              1            1        1          0           1     1
# 00862              2            2        2          0           2     2
# 00863              6            6        6          0           6     6
# 00869             17           17       17          0          17    17
# 0088             132          132      132          0         132   132
# 0090              25           25       25          0          25    25
# 0091              19           19       19          0          19    19
# 0092               5            5        5          0           5     5
# 0093               4            4        4          0           4     4
# 01085              2            2        2          0           2     2
# 01123              1            1        1          0           1     1
# 01136              1            1        1          0           1     1
# ...              ...          ...      ...        ...         ...   ...
# V8531             16           16       16          0          16    16
# V8532             19           19       19          0          19    19
# V8533             16           16       16          0          16    16
# V8534             18           18       18          0          18    18
# V8535             14           14       14          0          14    14
# V8536             23           23       23          0          23    23
# V8537             17           17       17          0          17    17
# V8538             20           20       20          0          20    20
# V8539             19           19       19          0          19    19
# V854              93           93       93          0          93    93
# V8541             84           84       84          0          84    84
# V8542             45           45       45          0          45    45
# V8543             50           50       50          0          50    50
# V8544             18           18       18          0          18    18
# V8545             11           11       11          0          11    11
# V860               8            8        8          0           8     8
# V861               2            2        2          0           2     2
# V8709              1            1        1          0           1     1
# V872               4            4        4          0           4     4
# V8741            400          400      400          0         400   400
# V8745              1            1        1          0           1     1
# V8801            153          153      153          0         153   153
# V8811              1            1        1          0           1     1
# V8812              7            7        7          0           7     7
# V8821              3            3        3          0           3     3
# V9010              1            1        1          0           1     1
# V9039              1            1        1          0           1     1
# V9081              3            3        3          0           3     3
# V9089              1            1        1          0           1     1
# V9103              1            1        1          0           1     1
#
#            TopLevelICD  Unnamed: 0    V9
# ICD9_CODE
# 0030                 2           2     2
# 0031                 1           1     1
# 0038                 2           2     2
# 0039                 1           1     1
# 0041                 3           3     3
# 0048                 1           1     1
# 0049                 1           1     1
# 0051                 1           1     1
# 00581                2           2     2
# 0059                 1           1     1
# 0071                 1           1     1
# 0074                 6           6     6
# 00804                1           1     1
# 00841                1           1     1
# 00843                1           1     1
# 00845             1428        1428  1428
# 00847                1           1     1
# 0085                 4           4     4
# 00861                1           1     1
# 00862                2           2     2
# 00863                6           6     6
# 00869               17          17    17
# 0088               132         132   132
# 0090                25          25    25
# 0091                19          19    19
# 0092                 5           5     5
# 0093                 4           4     4
# 01085                2           2     2
# 01123                1           1     1
# 01136                1           1     1
# ...                ...         ...   ...
# V8531               16          16    16
# V8532               19          19    19
# V8533               16          16    16
# V8534               18          18    18
# V8535               14          14    14
# V8536               23          23    23
# V8537               17          17    17
# V8538               20          20    20
# V8539               19          19    19
# V854                93          93    93
# V8541               84          84    84
# V8542               45          45    45
# V8543               50          50    50
# V8544               18          18    18
# V8545               11          11    11
# V860                 8           8     8
# V861                 2           2     2
# V8709                1           1     1
# V872                 4           4     4
# V8741              400         400   400
# V8745                1           1     1
# V8801              153         153   153
# V8811                1           1     1
# V8812                7           7     7
# V8821                3           3     3
# V9010                1           1     1
# V9039                1           1     1
# V9081                3           3     3
# V9089                1           1     1
# V9103                1           1     1
#
# [6918 rows x 9 columns]

# %%
mimic2.reset_index(inplace=True)
mimic2
# Out:
#      ICD9_CODE  CHARTDATE  DESCRIPTION  HADM_ID  Level2ICD  SUBJECT_ID  TEXT  \
# 0         0030          2            2        2          0           2     2
# 1         0031          1            1        1          0           1     1
# 2         0038          2            2        2          0           2     2
# 3         0039          1            1        1          0           1     1
# 4         0041          3            3        3          0           3     3
# 5         0048          1            1        1          0           1     1
# 6         0049          1            1        1          0           1     1
# 7         0051          1            1        1          0           1     1
# 8        00581          2            2        2          0           2     2
# 9         0059          1            1        1          0           1     1
# 10        0071          1            1        1          0           1     1
# 11        0074          6            6        6          0           6     6
# 12       00804          1            1        1          0           1     1
# 13       00841          1            1        1          0           1     1
# 14       00843          1            1        1          0           1     1
# 15       00845       1428         1428     1428          0        1428  1428
# 16       00847          1            1        1          0           1     1
# 17        0085          4            4        4          0           4     4
# 18       00861          1            1        1          0           1     1
# 19       00862          2            2        2          0           2     2
# 20       00863          6            6        6          0           6     6
# 21       00869         17           17       17          0          17    17
# 22        0088        132          132      132          0         132   132
# 23        0090         25           25       25          0          25    25
# 24        0091         19           19       19          0          19    19
# 25        0092          5            5        5          0           5     5
# 26        0093          4            4        4          0           4     4
# 27       01085          2            2        2          0           2     2
# 28       01123          1            1        1          0           1     1
# 29       01136          1            1        1          0           1     1
# ...        ...        ...          ...      ...        ...         ...   ...
# 6888     V8531         16           16       16          0          16    16
# 6889     V8532         19           19       19          0          19    19
# 6890     V8533         16           16       16          0          16    16
# 6891     V8534         18           18       18          0          18    18
# 6892     V8535         14           14       14          0          14    14
# 6893     V8536         23           23       23          0          23    23
# 6894     V8537         17           17       17          0          17    17
# 6895     V8538         20           20       20          0          20    20
# 6896     V8539         19           19       19          0          19    19
# 6897      V854         93           93       93          0          93    93
# 6898     V8541         84           84       84          0          84    84
# 6899     V8542         45           45       45          0          45    45
# 6900     V8543         50           50       50          0          50    50
# 6901     V8544         18           18       18          0          18    18
# 6902     V8545         11           11       11          0          11    11
# 6903      V860          8            8        8          0           8     8
# 6904      V861          2            2        2          0           2     2
# 6905     V8709          1            1        1          0           1     1
# 6906      V872          4            4        4          0           4     4
# 6907     V8741        400          400      400          0         400   400
# 6908     V8745          1            1        1          0           1     1
# 6909     V8801        153          153      153          0         153   153
# 6910     V8811          1            1        1          0           1     1
# 6911     V8812          7            7        7          0           7     7
# 6912     V8821          3            3        3          0           3     3
# 6913     V9010          1            1        1          0           1     1
# 6914     V9039          1            1        1          0           1     1
# 6915     V9081          3            3        3          0           3     3
# 6916     V9089          1            1        1          0           1     1
# 6917     V9103          1            1        1          0           1     1
#
#       TopLevelICD  Unnamed: 0    V9
# 0               2           2     2
# 1               1           1     1
# 2               2           2     2
# 3               1           1     1
# 4               3           3     3
# 5               1           1     1
# 6               1           1     1
# 7               1           1     1
# 8               2           2     2
# 9               1           1     1
# 10              1           1     1
# 11              6           6     6
# 12              1           1     1
# 13              1           1     1
# 14              1           1     1
# 15           1428        1428  1428
# 16              1           1     1
# 17              4           4     4
# 18              1           1     1
# 19              2           2     2
# 20              6           6     6
# 21             17          17    17
# 22            132         132   132
# 23             25          25    25
# 24             19          19    19
# 25              5           5     5
# 26              4           4     4
# 27              2           2     2
# 28              1           1     1
# 29              1           1     1
# ...           ...         ...   ...
# 6888           16          16    16
# 6889           19          19    19
# 6890           16          16    16
# 6891           18          18    18
# 6892           14          14    14
# 6893           23          23    23
# 6894           17          17    17
# 6895           20          20    20
# 6896           19          19    19
# 6897           93          93    93
# 6898           84          84    84
# 6899           45          45    45
# 6900           50          50    50
# 6901           18          18    18
# 6902           11          11    11
# 6903            8           8     8
# 6904            2           2     2
# 6905            1           1     1
# 6906            4           4     4
# 6907          400         400   400
# 6908            1           1     1
# 6909          153         153   153
# 6910            1           1     1
# 6911            7           7     7
# 6912            3           3     3
# 6913            1           1     1
# 6914            1           1     1
# 6915            3           3     3
# 6916            1           1     1
# 6917            1           1     1
#
# [6918 rows x 10 columns]

# %%
list(mimic2)
# Out:
# ['ICD9_CODE',
#  'CHARTDATE',
#  'DESCRIPTION',
#  'HADM_ID',
#  'Level2ICD',
#  'SUBJECT_ID',
#  'TEXT',
#  'TopLevelICD',
#  'Unnamed: 0',
#  'V9']

# %%
mimic2.drop(['DESCRIPTION',
 'HADM_ID',
 'Level2ICD',
 'SUBJECT_ID',
 'TEXT',
 'TopLevelICD',
 'Unnamed: 0',
 'V9'], axis=1, inplace=True)
mimic2
# Out:
#      ICD9_CODE  CHARTDATE
# 0         0030          2
# 1         0031          1
# 2         0038          2
# 3         0039          1
# 4         0041          3
# 5         0048          1
# 6         0049          1
# 7         0051          1
# 8        00581          2
# 9         0059          1
# 10        0071          1
# 11        0074          6
# 12       00804          1
# 13       00841          1
# 14       00843          1
# 15       00845       1428
# 16       00847          1
# 17        0085          4
# 18       00861          1
# 19       00862          2
# 20       00863          6
# 21       00869         17
# 22        0088        132
# 23        0090         25
# 24        0091         19
# 25        0092          5
# 26        0093          4
# 27       01085          2
# 28       01123          1
# 29       01136          1
# ...        ...        ...
# 6888     V8531         16
# 6889     V8532         19
# 6890     V8533         16
# 6891     V8534         18
# 6892     V8535         14
# 6893     V8536         23
# 6894     V8537         17
# 6895     V8538         20
# 6896     V8539         19
# 6897      V854         93
# 6898     V8541         84
# 6899     V8542         45
# 6900     V8543         50
# 6901     V8544         18
# 6902     V8545         11
# 6903      V860          8
# 6904      V861          2
# 6905     V8709          1
# 6906      V872          4
# 6907     V8741        400
# 6908     V8745          1
# 6909     V8801        153
# 6910     V8811          1
# 6911     V8812          7
# 6912     V8821          3
# 6913     V9010          1
# 6914     V9039          1
# 6915     V9081          3
# 6916     V9089          1
# 6917     V9103          1
#
# [6918 rows x 2 columns]

# %%
mimic2.rename(columns={'CHARTDATE':'count'}, inplace=True)
mimic2
# Out:
#      ICD9_CODE  count
# 0         0030      2
# 1         0031      1
# 2         0038      2
# 3         0039      1
# 4         0041      3
# 5         0048      1
# 6         0049      1
# 7         0051      1
# 8        00581      2
# 9         0059      1
# 10        0071      1
# 11        0074      6
# 12       00804      1
# 13       00841      1
# 14       00843      1
# 15       00845   1428
# 16       00847      1
# 17        0085      4
# 18       00861      1
# 19       00862      2
# 20       00863      6
# 21       00869     17
# 22        0088    132
# 23        0090     25
# 24        0091     19
# 25        0092      5
# 26        0093      4
# 27       01085      2
# 28       01123      1
# 29       01136      1
# ...        ...    ...
# 6888     V8531     16
# 6889     V8532     19
# 6890     V8533     16
# 6891     V8534     18
# 6892     V8535     14
# 6893     V8536     23
# 6894     V8537     17
# 6895     V8538     20
# 6896     V8539     19
# 6897      V854     93
# 6898     V8541     84
# 6899     V8542     45
# 6900     V8543     50
# 6901     V8544     18
# 6902     V8545     11
# 6903      V860      8
# 6904      V861      2
# 6905     V8709      1
# 6906      V872      4
# 6907     V8741    400
# 6908     V8745      1
# 6909     V8801    153
# 6910     V8811      1
# 6911     V8812      7
# 6912     V8821      3
# 6913     V9010      1
# 6914     V9039      1
# 6915     V9081      3
# 6916     V9089      1
# 6917     V9103      1
#
# [6918 rows x 2 columns]

# %%
mimic2.sort_values('count', inplace=True, ascending=False)
display(mimic2[:5])
# Out:
#      ICD9_CODE  count
# 1957      4019  20053
# 2104      4280  12842
# 2093     42731  12594
# 2014     41401  12179
# 2950      5849   8907

# %%
mimic2.rename(columns={'conceptID':'conceptId'}, inplace=True)
mimic2[:2]
# Out:
#      conceptId  count
# 1957      4019  20053
# 2104      4280  12842

# %%
code_desc = pd.merge(mimic2,desc[['conceptId','term']]
                                   ,on='conceptId', how='left')
code_desc[:10]
# Out:
#   conceptId  count                       term
# 0      4019  20053           Hypertension NOS
# 1      4280  12842                    CHF NOS
# 2     42731  12594        Atrial fibrillation
# 3     41401  12179   Crnry athrscl natve vssl
# 4      5849   8907   Acute kidney failure NOS
# 5     25000   8784   DMII wo cmp nt st uncntr
# 6      2724   8504     Hyperlipidemia NEC/NOS
# 7     51881   7249   Acute respiratry failure
# 8      5990   6442   Urin tract infection NOS
# 9     53081   6156          Esophageal reflux

# %%
code_desc.to_csv('mimic_code_counts', sep='\t', index=False)
